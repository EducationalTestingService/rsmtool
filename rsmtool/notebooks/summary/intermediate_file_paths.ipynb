# %% [markdown]
# ## Links to intermediate files

# %% [markdown]
# The following intermediate files were generated as part of this experiment. To examine a file, click on the link. Note that the descriptions provided here are only brief summaries. For more detailed descriptions, please refer to the [RSMTool documentation](https://rsmtool.readthedocs.io).
# **Note**: This list only includes the intermediate files generated by `rsmsummarize`, *not* the intermediate files generated by the original experiment(s).

# %%
from rsmtool.utils.notebook import show_files

# %%
show_files(context, output_dir, summary_id, file_format_summarize)
